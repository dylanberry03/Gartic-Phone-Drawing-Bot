# %%
pip install opencv-python
# Out:
# WARNING: You are using pip version 21.2.1; however, version 21.2.2 is available.
# You should consider upgrading via the 'C:\Users\dylan\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.1; however, version 21.2.2 is available.
# You should consider upgrading via the 'C:\Users\dylan\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install pyautogui
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.1; however, version 21.2.2 is available.
# You should consider upgrading via the 'C:\Users\dylan\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install mss
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.1; however, version 21.2.2 is available.
# You should consider upgrading via the 'C:\Users\dylan\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install keyboard
# Out:
# ...
# WARNING: You are using pip version 21.2.1; however, version 21.2.2 is available.
# You should consider upgrading via the 'C:\Users\dylan\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import numpy as np
import pyautogui
import mss
import keyboard
from PIL import Image
from time import time, sleep

# %%
while True:
    
    if keyboard.is_pressed('m'):
        
        dimensions_canvas = { ### YOU MAY NEED TO CHANGE LEFT AND TOP TO THE TOP LEFT OF GARTIC'S DRAWING SPACE
        'left': 518,
        'top': 341,
        'width': 882,
        'height': 491 
        }

        x = 518  ### SAME AS dimensions_canvas ### x IS LEFT y IS TOP
        y = 341
        we = 880
        he = 490

        print('Press o to select Point 1')
        keyboard.wait('o')
        point1x, point1y = pyautogui.position()

        print('Press n to select Point 2')
        keyboard.wait('n')
        point2x, point2y = pyautogui.position()

        x1 = point1x
        y1 = point1y
        x2 = (point2x - point1x)
        y2 = (point2y - point1y)

        dimensions_scr = {
            'left': x1,
            'top': y1,
            'width': x2,
            'height': y2
            }

        with mss.mss() as sct:
            imga = sct.grab(dimensions_scr)
            output_filename = 'image.png'
            img = Image.frombytes("RGB", imga.size, imga.bgra, "raw", "BGRX")
            img.save(output_filename, "PNG")

        pyautogui.PAUSE = 0

        black = (0, 0, 0) ### DO NOT CHANGE THESE, THEY ARE THE AVAILABLE COLORS' color codes
        grey = (102, 102, 102)
        blue = (205, 80, 0)

        white = (255, 255, 255)
        ligrey = (170, 170, 170)
        teal = (255, 201, 38)

        green = (1, 116, 32)
        darbrown = (6, 21, 105)
        brown = (18, 65, 150)

        ligreen = (60, 176, 17)
        red = (19, 0, 255)
        orange = (41, 120, 255)

        librown = (28, 112, 176)
        purple = (78, 0, 153)
        coral = (87, 90, 203)

        yellow = (78, 193, 255)
        magenta = (143, 0, 255)
        pink = (168, 175, 254)

        blackList = []
        greyList = []
        blueList = []
        whiteList = []
        ligreyList = []
        tealList = []
        greenList = []
        darbrownList = []
        brownList = []
        ligreenList = []
        redList = []
        orangeList = []
        librownList = []
        purpleList = []
        coralList = []
        yellowList = []
        magentaList = []
        pinkList = []

        im = Image.open('image.png')
        rgb_im = im.convert('RGB')
        size = (880, 490)
        rgb_ima = rgb_im.resize(size)

        j = 0
        h = 0
        n = 5 ###### CHANGE HOW OFTEN TO COPY COLOR. HIGHER n means higher quality but longer time USUALLY GO BY 5 FOR THE STANDARD SIZE GARTIC GIVES
        list_of_colors = [black, grey, blue, white, ligrey, teal, green, darbrown, brown, ligreen, red, orange, librown, purple, coral, yellow, magenta, pink]

        while j < (size[0] - n):
            while h < (size[1] - n):
                b, g, r = rgb_ima.getpixel((j, h))

                color = [r, g, b]

                def closest(colors, color):
                    colors = np.array(colors)
                    color = np.array(color)
                    distances = np.sqrt(np.sum((colors-color)**2,axis=1))
                    index_of_smallest = np.where(distances==np.amin(distances))
                    smallest_distance = colors[index_of_smallest]
                    return smallest_distance 

                closest_color = closest(list_of_colors, color)

                if closest_color[0][0] == white[0] and closest_color[0][1] == white[1] and closest_color[0][2] == white[2]:
                    whiteList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == teal[0] and closest_color[0][1] == teal[1] and closest_color[0][2] == teal[2]:
                    tealList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == magenta[0] and closest_color[0][1] == magenta[1] and closest_color[0][2] == magenta[2]:
                    magentaList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == yellow[0] and closest_color[0][1] == yellow[1] and closest_color[0][2] == yellow[2]:
                    yellowList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == blue[0] and closest_color[0][1] == blue[1] and closest_color[0][2] == blue[2]:
                    blueList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == green[0] and closest_color[0][1] == green[1] and closest_color[0][2] == green[2]:
                    greenList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == red[0] and closest_color[0][1] == red[1] and closest_color[0][2] == red[2]:
                    redList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == black[0] and closest_color[0][1] == black[1] and closest_color[0][2] == black[2]:
                    blackList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == orange[0] and closest_color[0][1] == orange[1] and closest_color[0][2] == orange[2]:
                    orangeList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == grey[0] and closest_color[0][1] == grey[1] and closest_color[0][2] == grey[2]:
                    greyList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == ligrey[0] and closest_color[0][1] == ligrey[1] and closest_color[0][2] == ligrey[2]:
                    ligreyList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == darbrown[0] and closest_color[0][1] == darbrown[1] and closest_color[0][2] == darbrown[2]:
                    darbrownList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == brown[0] and closest_color[0][1] == brown[1] and closest_color[0][2] == brown[2]:
                    brownList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == ligreen[0] and closest_color[0][1] == ligreen[1] and closest_color[0][2] == ligreen[2]:
                    ligreenList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == librown[0] and closest_color[0][1] == librown[1] and closest_color[0][2] == librown[2]:
                    librownList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == purple[0] and closest_color[0][1] == purple[1] and closest_color[0][2] == purple[2]:
                    purpleList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == coral[0] and closest_color[0][1] == coral[1] and closest_color[0][2] == coral[2]:
                    coralList.append((j, h))
                    h = h + n
                elif closest_color[0][0] == pink[0] and closest_color[0][1] == pink[1] and closest_color[0][2] == pink[2]:
                    pinkList.append((j, h))
                    h = h + n
                else:
                    h = h + n
                
                if h == (size[1] - n):
                    j = j + n
                    h = 0
                    break

            if j == (size[0] - n):
                break

        tim = .025
        print("Start by pressing 'k'.")
        print("Once started press 'p' to quit.")
        keyboard.wait('k')

        colNum = 0
        i = 0

        while True:
            if keyboard.is_pressed('g'):
                break

            if colNum == 0:
                sleep(.25)
                pyautogui.click(372, 475)  ##IF DIMENSIONS DO NOT LINE UP YOU WILL HAVE TO CHANGE EVERYONE OF THESE COORDS FOR EACH COLOR
                sleep(.25)
                pyautogui.click(372, 475) ## THE SECOND ONE TOO
                sleep(.25)
                while i < len(whiteList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(whiteList[i][0] + 518, whiteList[i][1] + 341) ## THE 518 and 341 LISTED HERE ARE THE x AND y VALUES FROM THE VERY TOP IF YOUR SCREEN DIMESION IS DIFFERENT THEY ALL HAVE TO CHANGE FOR EACH COLOR
                    sleep(tim)
                    i = i + 1
                
                i = 0
                colNum = colNum + 1

            if colNum == 1:
                sleep(.25)
                pyautogui.click(458, 474) ## ON EVERY COLOR
                sleep(.25)
                pyautogui.click(458, 474) ## ALL OF THEM
                sleep(.25)
                while i < len(tealList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(tealList[i][0] + 518, tealList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 2:
                sleep(.25)
                pyautogui.click(414, 661)
                sleep(.25)
                pyautogui.click(414, 661)
                sleep(.25)
                while i < len(magentaList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(magentaList[i][0] + 518, magentaList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 3:
                sleep(.25)
                pyautogui.click(371, 662)
                sleep(.25)
                pyautogui.click(371, 662)
                sleep(.25)
                while i < len(yellowList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(yellowList[i][0] + 518, yellowList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 4:
                sleep(.25)
                pyautogui.click(459, 424)
                sleep(.25)
                pyautogui.click(459, 424)
                sleep(.25)
                while i < len(blueList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(blueList[i][0] + 518, blueList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 5:
                sleep(.25)
                pyautogui.click(370, 517)
                sleep(.25)
                pyautogui.click(370, 517)
                sleep(.25)
                while i < len(greenList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(greenList[i][0] + 518, greenList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 6:
                sleep(.25)
                pyautogui.click(411, 567)
                sleep(.25)
                pyautogui.click(411, 567)
                sleep(.25)
                while i < len(redList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(redList[i][0] + 518, redList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 7:
                sleep(.25)
                pyautogui.click(373, 427)
                sleep(.25)
                pyautogui.click(373, 427)
                sleep(.25)
                while i < len(blackList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(blackList[i][0] + 518, blackList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 8:
                sleep(.25)
                pyautogui.click(458, 568)
                sleep(.25)
                pyautogui.click(458, 568)
                sleep(.25)
                while i < len(orangeList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(orangeList[i][0] + 518, orangeList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 9:
                sleep(.25)
                pyautogui.click(415, 428)
                sleep(.25)
                pyautogui.click(415, 428)
                sleep(.25)
                while i < len(greyList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(greyList[i][0] + 518, greyList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 10:
                sleep(.25)
                pyautogui.click(416, 474)
                sleep(.25)
                pyautogui.click(416, 474)
                sleep(.25)
                while i < len(ligreyList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(ligreyList[i][0] + 518, ligreyList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 11:
                sleep(.25)
                pyautogui.click(417, 520)
                sleep(.25)
                pyautogui.click(417, 520)
                sleep(.25)
                while i < len(darbrownList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(darbrownList[i][0] + 518, darbrownList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 12:
                sleep(.25)
                pyautogui.click(459, 517)
                sleep(.25)
                pyautogui.click(459, 517)
                sleep(.25)
                while i < len(brownList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(brownList[i][0] + 518, brownList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 13:
                sleep(.25)
                pyautogui.click(370, 568)
                sleep(.25)
                pyautogui.click(370, 568)
                sleep(.25)
                while i < len(ligreenList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(ligreenList[i][0] + 518, ligreenList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 14:
                sleep(.25)
                pyautogui.click(369, 612)
                sleep(.25)
                pyautogui.click(369, 612)
                sleep(.25)
                while i < len(librownList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(librownList[i][0] + 518, librownList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 15:
                sleep(.25)
                pyautogui.click(413, 616)
                sleep(.25)
                pyautogui.click(413, 616)
                sleep(.25)
                while i < len(purpleList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(purpleList[i][0] + 518, purpleList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 16:
                sleep(.25)
                pyautogui.click(458, 615)
                sleep(.25)
                pyautogui.click(458, 615)
                sleep(.25)
                while i < len(coralList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(coralList[i][0] + 518, coralList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 17:
                sleep(.25)
                pyautogui.click(458, 664)
                sleep(.25)
                pyautogui.click(458, 664)
                sleep(.25)
                while i < len(pinkList):

                    if keyboard.is_pressed('p'):
                        break

                    pyautogui.click(pinkList[i][0] + 518, pinkList[i][1] + 341)
                    sleep(tim)
                    i = i + 1

                i = 0
                colNum = colNum + 1

            if colNum == 18:
                break
# Out:
# Press o to select Point 1
# Press n to select Point 2
# Start by pressing 'k'.
# Once started press 'p' to quit.
# Press o to select Point 1
# Press n to select Point 2
# Start by pressing 'k'.
# Once started press 'p' to quit.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27116/2188205297.py in <module>
#       1 while True:
#       2
# ----> 3     if keyboard.is_pressed('m'):
#       4
#       5         dimensions_canvas = {
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\keyboard\__init__.py in is_pressed(hotkey)
#     415             return hotkey in _pressed_events
#     416
# --> 417     steps = parse_hotkey(hotkey)
#     418     if len(steps) > 1:
#     419         raise ValueError("Impossible to check if multi-step hotkeys are pressed (`a+b` is ok, `a, b` isn't).")
#
# ...

# %%
dimensions_canvas = {
    'left': 518,
    'top': 341,
    'width': 882,
    'height': 491 
    }

x = 518
y = 341
we = 880
he = 490

print('Press o to select Point 1')
keyboard.wait('o')
point1x, point1y = pyautogui.position()

print('Press o to select Point 1')
keyboard.wait('o')
point2x, point2y = pyautogui.position()

x1 = point1x
y1 = point1y
x2 = (point2x - point1x)
y2 = (point2y - point1y)

dimensions_scr = {
    'left': x1,
    'top': y1,
    'width': x2,
    'height': y2
    }

with mss.mss() as sct:
    imga = sct.grab(dimensions_scr)
    output_filename = 'image.png'
    img = Image.frombytes("RGB", imga.size, imga.bgra, "raw", "BGRX")
    img.save(output_filename, "PNG")

pyautogui.PAUSE = 0

black = (0, 0, 0)
grey = (102, 102, 102)
blue = (205, 80, 0)

white = (255, 255, 255)
ligrey = (170, 170, 170)
teal = (255, 201, 38)

green = (1, 116, 32)
darbrown = (6, 21, 105)
brown = (18, 65, 150)

ligreen = (60, 176, 17)
red = (19, 0, 255)
orange = (41, 120, 255)

librown = (28, 112, 176)
purple = (78, 0, 153)
coral = (87, 90, 203)

yellow = (78, 193, 255)
magenta = (143, 0, 255)
pink = (168, 175, 254)

blackList = []
greyList = []
blueList = []
whiteList = []
ligreyList = []
tealList = []
greenList = []
darbrownList = []
brownList = []
ligreenList = []
redList = []
orangeList = []
librownList = []
purpleList = []
coralList = []
yellowList = []
magentaList = []
pinkList = []

im = Image.open('image.png')
rgb_im = im.convert('RGB')
size = (880, 490)
rgb_ima = rgb_im.resize(size)

j = 0
h = 0
n = 5
list_of_colors = [black, grey, blue, white, ligrey, teal, green, darbrown, brown, ligreen, red, orange, librown, purple, coral, yellow, magenta, pink]

while j < (size[0] - n):
    while h < (size[1] - n):
        b, g, r = rgb_ima.getpixel((j, h))

        color = [r, g, b]

        def closest(colors, color):
            colors = np.array(colors)
            color = np.array(color)
            distances = np.sqrt(np.sum((colors-color)**2,axis=1))
            index_of_smallest = np.where(distances==np.amin(distances))
            smallest_distance = colors[index_of_smallest]
            return smallest_distance 

        closest_color = closest(list_of_colors, color)

        if closest_color[0][0] == white[0] and closest_color[0][1] == white[1] and closest_color[0][2] == white[2]:
            whiteList.append((j, h))
            h = h + n
        elif closest_color[0][0] == teal[0] and closest_color[0][1] == teal[1] and closest_color[0][2] == teal[2]:
            tealList.append((j, h))
            h = h + n
        elif closest_color[0][0] == magenta[0] and closest_color[0][1] == magenta[1] and closest_color[0][2] == magenta[2]:
            magentaList.append((j, h))
            h = h + n
        elif closest_color[0][0] == yellow[0] and closest_color[0][1] == yellow[1] and closest_color[0][2] == yellow[2]:
            yellowList.append((j, h))
            h = h + n
        elif closest_color[0][0] == blue[0] and closest_color[0][1] == blue[1] and closest_color[0][2] == blue[2]:
            blueList.append((j, h))
            h = h + n
        elif closest_color[0][0] == green[0] and closest_color[0][1] == green[1] and closest_color[0][2] == green[2]:
            greenList.append((j, h))
            h = h + n
        elif closest_color[0][0] == red[0] and closest_color[0][1] == red[1] and closest_color[0][2] == red[2]:
            redList.append((j, h))
            h = h + n
        elif closest_color[0][0] == black[0] and closest_color[0][1] == black[1] and closest_color[0][2] == black[2]:
            blackList.append((j, h))
            h = h + n
        elif closest_color[0][0] == orange[0] and closest_color[0][1] == orange[1] and closest_color[0][2] == orange[2]:
            orangeList.append((j, h))
            h = h + n
        elif closest_color[0][0] == grey[0] and closest_color[0][1] == grey[1] and closest_color[0][2] == grey[2]:
            greyList.append((j, h))
            h = h + n
        elif closest_color[0][0] == ligrey[0] and closest_color[0][1] == ligrey[1] and closest_color[0][2] == ligrey[2]:
            ligreyList.append((j, h))
            h = h + n
        elif closest_color[0][0] == darbrown[0] and closest_color[0][1] == darbrown[1] and closest_color[0][2] == darbrown[2]:
            darbrownList.append((j, h))
            h = h + n
        elif closest_color[0][0] == brown[0] and closest_color[0][1] == brown[1] and closest_color[0][2] == brown[2]:
            brownList.append((j, h))
            h = h + n
        elif closest_color[0][0] == ligreen[0] and closest_color[0][1] == ligreen[1] and closest_color[0][2] == ligreen[2]:
            ligreenList.append((j, h))
            h = h + n
        elif closest_color[0][0] == librown[0] and closest_color[0][1] == librown[1] and closest_color[0][2] == librown[2]:
            librownList.append((j, h))
            h = h + n
        elif closest_color[0][0] == purple[0] and closest_color[0][1] == purple[1] and closest_color[0][2] == purple[2]:
            purpleList.append((j, h))
            h = h + n
        elif closest_color[0][0] == coral[0] and closest_color[0][1] == coral[1] and closest_color[0][2] == coral[2]:
            coralList.append((j, h))
            h = h + n
        elif closest_color[0][0] == pink[0] and closest_color[0][1] == pink[1] and closest_color[0][2] == pink[2]:
            pinkList.append((j, h))
            h = h + n
        else:
            h = h + n
        
        if h == (size[1] - n):
            j = j + n
            h = 0
            break

    if j == (size[0] - n):
        break

tim = .025
print("Start by pressing 'k'.")
print("Once started press 'p' to quit.")
keyboard.wait('k')

colNum = 0
i = 0

while True:
    if keyboard.is_pressed('g'):
        break

    if colNum == 0:
        sleep(.25)
        pyautogui.click(372, 475)
        sleep(.25)
        pyautogui.click(372, 475)
        sleep(.25)
        while i < len(whiteList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(whiteList[i][0] + 518, whiteList[i][1] + 341)
            sleep(tim)
            i = i + 1
        
        i = 0
        colNum = colNum + 1

    if colNum == 1:
        sleep(.25)
        pyautogui.click(458, 474)
        sleep(.25)
        pyautogui.click(458, 474)
        sleep(.25)
        while i < len(tealList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(tealList[i][0] + 518, tealList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 2:
        sleep(.25)
        pyautogui.click(414, 661)
        sleep(.25)
        pyautogui.click(414, 661)
        sleep(.25)
        while i < len(magentaList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(magentaList[i][0] + 518, magentaList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 3:
        sleep(.25)
        pyautogui.click(371, 662)
        sleep(.25)
        pyautogui.click(371, 662)
        sleep(.25)
        while i < len(yellowList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(yellowList[i][0] + 518, yellowList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 4:
        sleep(.25)
        pyautogui.click(459, 424)
        sleep(.25)
        pyautogui.click(459, 424)
        sleep(.25)
        while i < len(blueList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(blueList[i][0] + 518, blueList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 5:
        sleep(.25)
        pyautogui.click(370, 517)
        sleep(.25)
        pyautogui.click(370, 517)
        sleep(.25)
        while i < len(greenList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(greenList[i][0] + 518, greenList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 6:
        sleep(.25)
        pyautogui.click(411, 567)
        sleep(.25)
        pyautogui.click(411, 567)
        sleep(.25)
        while i < len(redList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(redList[i][0] + 518, redList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 7:
        sleep(.25)
        pyautogui.click(373, 427)
        sleep(.25)
        pyautogui.click(373, 427)
        sleep(.25)
        while i < len(blackList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(blackList[i][0] + 518, blackList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 8:
        sleep(.25)
        pyautogui.click(458, 568)
        sleep(.25)
        pyautogui.click(458, 568)
        sleep(.25)
        while i < len(orangeList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(orangeList[i][0] + 518, orangeList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 9:
        sleep(.25)
        pyautogui.click(415, 428)
        sleep(.25)
        pyautogui.click(415, 428)
        sleep(.25)
        while i < len(greyList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(greyList[i][0] + 518, greyList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 10:
        sleep(.25)
        pyautogui.click(416, 474)
        sleep(.25)
        pyautogui.click(416, 474)
        sleep(.25)
        while i < len(ligreyList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(ligreyList[i][0] + 518, ligreyList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 11:
        sleep(.25)
        pyautogui.click(417, 520)
        sleep(.25)
        pyautogui.click(417, 520)
        sleep(.25)
        while i < len(darbrownList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(darbrownList[i][0] + 518, darbrownList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 12:
        sleep(.25)
        pyautogui.click(459, 517)
        sleep(.25)
        pyautogui.click(459, 517)
        sleep(.25)
        while i < len(brownList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(brownList[i][0] + 518, brownList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 13:
        sleep(.25)
        pyautogui.click(370, 568)
        sleep(.25)
        pyautogui.click(370, 568)
        sleep(.25)
        while i < len(ligreenList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(ligreenList[i][0] + 518, ligreenList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 14:
        sleep(.25)
        pyautogui.click(369, 612)
        sleep(.25)
        pyautogui.click(369, 612)
        sleep(.25)
        while i < len(librownList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(librownList[i][0] + 518, librownList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 15:
        sleep(.25)
        pyautogui.click(413, 616)
        sleep(.25)
        pyautogui.click(413, 616)
        sleep(.25)
        while i < len(purpleList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(purpleList[i][0] + 518, purpleList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 16:
        sleep(.25)
        pyautogui.click(458, 615)
        sleep(.25)
        pyautogui.click(458, 615)
        sleep(.25)
        while i < len(coralList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(coralList[i][0] + 518, coralList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 17:
        sleep(.25)
        pyautogui.click(458, 664)
        sleep(.25)
        pyautogui.click(458, 664)
        sleep(.25)
        while i < len(pinkList):

            if keyboard.is_pressed('p'):
                break

            pyautogui.click(pinkList[i][0] + 518, pinkList[i][1] + 341)
            sleep(tim)
            i = i + 1

        i = 0
        colNum = colNum + 1

    if colNum == 18:
        break
# Out:
# Press o to select Point 1
# Press o to select Point 1
# Start by pressing 'k'.
# Once started press 'p' to quit.

# %%
print("Start by pressing 'k'.")
print("Once started press 'p' to quit.")
keyboard.wait('k')
x, y = pyautogui.position()
print(x)
print(y)
# Out:
# Start by pressing 'k'.
# Once started press 'p' to quit.
# 459
# 664
